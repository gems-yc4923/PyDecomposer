# %%
import pydecomposer
from pydecomposer import DecompositionModel

# %%
import numpy as np
from pydecomposer import DecompositionModel

# Generate a sample signal
t = np.linspace(0, 1, 1000)
signal = np.sin(2*np.pi*10*t) + 0.5*np.sin(2*np.pi*50*t)

# Create a DecompositionModel instance
model = DecompositionModel()

# Execute the decomposition
model.run(signal)

# Get the decomposed signals
high_freq, medium_freq, low_freq, residual = model.get_signals()
# Out:
# Decomposing signal using VMD...
# Number of low frequency IMFs: 4 with: 7 IMFs
# Number of IMFs from VMD: 7
# Decomposing signal using CEEMDAN...
# Number of IMFs from CEEMDAN: 6
# This signal does not have much effects on the short term, and is more of a long term trend.
# Adding 3 additional IMFs.
# This signal has few low frequency components.
# ...
# Decomposition completed successfully.
# Original signal, residual (long term trend), low, medium and high frequency signals are stored as instance variables.
# Use function get_signals() to retrieve the decomposed signals.
# Use function plot_signals() to visualize the decomposed signals.
# Decomposed signals are stored as instance variables. Please use get_signals() to retrieve the decomposed signals.
